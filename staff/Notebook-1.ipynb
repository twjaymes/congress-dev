# %%
import pandas as pd
import numpy as np
file_path = './output.parquet'  # Replace with your parquet file path

# Read the parquet file
df = pd.read_parquet(file_path)

# Display basic information about the dataset
print("Dataset Shape:", df.shape)
print("\nColumn Names and Types:")
print(df.dtypes)

# Display first few rows
print("\nFirst 5 rows:")
print(df.head())

# Display summary statistics
print("\nSummary Statistics:")
print(df.describe(include='all'))

# Display info about missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Display unique values for categorical columns (if any)
categorical_cols = df.select_dtypes(include=['object']).columns
if len(categorical_cols) > 0:
    print("\nUnique values in categorical columns:")
    for col in categorical_cols:
        print(f"{col}: {df[col].nunique()} unique values")
        if df[col].nunique() <= 10:
            print(f"Values: {df[col].unique()}")
# Out:
# Dataset Shape: (1501, 8)
#
# Column Names and Types:
# member_name       object
# member_party      object
# member_city       object
# member_state      object
# district          object
# office_address    object
# staff_position    object
# staff_name        object
# dtype: object
#
# First 5 rows:
#         member_name member_party  member_city member_state district  \
# 0  KAMALA D. HARRIS     Democrat  Los Angeles           CA     None
# 1  KAMALA D. HARRIS     Democrat  Los Angeles           CA     None
# 2  KAMALA D. HARRIS     Democrat  Los Angeles           CA     None
# 3  KAMALA D. HARRIS     Democrat  Los Angeles           CA     None
# 4  KAMALA D. HARRIS     Democrat  Los Angeles           CA     None
#
#   office_address                                     staff_position  \
# 0           None  Assistant to the President / Chief of Staff to...
# 1           None  Special Assistant to the President / Deputy Ch...
# 2           None  Special Assistant to the President / Domestic ...
# 3           None        Senior Policy Advisor to the Vice President
# 4           None       Deputy Policy Director to the Vice President
#
#            staff_name
# 0  Lorraine Ann Voles
# 1              Erin S
# 2      Rohini Kosoglu
# 3            Ike Irby
# 4     Deanne Millison
#
# Summary Statistics:
#          member_name member_party member_city member_state district  \
# count           1501         1501        1501         1501       21
# unique           179            2         165           45        1
# top     MIKE QUIGLEY     Democrat    New York           NY    First
# freq              18          753          40          117       21
#
#                             office_address           staff_position staff_name
# count                                 1471                     1501       1501
# unique                                 174                      363       1484
# top     2445 Rayburn House Office Building  Communications Director
# freq                                    18                      110          7
#
# Missing Values:
# member_name          0
# member_party         0
# member_city          0
# member_state         0
# district          1480
# office_address      30
# staff_position       0
# staff_name           0
# dtype: int64
#
# Unique values in categorical columns:
# member_name: 179 unique values
# member_party: 2 unique values
# Values: ['Democrat' 'Republican']
# member_city: 165 unique values
# member_state: 45 unique values
# district: 1 unique values
# Values: [None 'First']
# office_address: 174 unique values
# staff_position: 363 unique values
# staff_name: 1484 unique values
